# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/ProbAndStats_Sep24/blob/main/Probability_Distributions_1%7CLecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2024-09-28 at 7.03.31 AM.png](data:image/png;base64,...)

# %%
import pandas  as pd

df = pd.read_csv('https://raw.githubusercontent.com/SachinScaler/ProbAndStats_Sep24/refs/heads/main/weight-height.csv')

# %%
# mode
import seaborn as sns

sns.histplot(df, x='Height', kde = True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.kdeplot(df, x='Height')
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %% [markdown]
# #### Empirical

# %%
import math as m
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# let's simulate exp of picking balls from bag
bag = ['R','R', 'R', 'B', 'B']
rolls = np.random.choice(bag, size = 4, replace = True)
rolls
# Out:
# array(['R', 'B', 'B', 'R'], dtype='<U1')

# %%
rolls = np.random.choice(bag, size = 4, replace = True)
rolls
# Out:
# array(['R', 'R', 'R', 'R'], dtype='<U1')

# %%
sum(rolls == 'R')
# Out:
# 4

# %%
rolls = np.random.choice(bag, size = 4, replace = True)
print(rolls)
sum(rolls == 'R')
# Out:
# ['R' 'B' 'B' 'R']
# 2

# %%
red_vals = []
for _ in range(10000):
    rolls = np.random.choice(bag, size = 4, replace = True)
    count_r = sum(rolls == 'R')
    red_vals.append(count_r)

# %%
len(red_vals)
# Out:
# 10000

# %%
pd.Series(red_vals).value_counts()
# Out:
# 3    3472
# 2    3358
# 1    1579
# 4    1334
# 0     257
# Name: count, dtype: int64

# %%
pd.value_counts(red_vals, normalize=True)
# Out:
# <ipython-input-15-a4d7906ddec8>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(red_vals, normalize=True )
# <ipython-input-15-a4d7906ddec8>:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pd.value_counts(red_vals, normalize=True )
# 3    0.3472
# 2    0.3358
# 1    0.1579
# 4    0.1334
# 0    0.0257
# Name: proportion, dtype: float64

# %% [markdown]
# ### On an average, How many red balls a person gets
# HINT(Wieghed Mean)

# %% [markdown]
# resume@8:30

# %% [markdown]
# Expection of profit:
# ?

# %%
import math
# nCk, n = 4, k = 0
math.comb(4,0)
# Out:
# 1

# %%
math.comb(4,2)
# Out:
# 6

# %% [markdown]
# ### x = 0 red ball

# %%
math.comb(4,0) * ((3/5)**0) * ((2/5)**4)
# Out:
# 0.025600000000000005

# %%
math.comb(4,1) * ((3/5)**1) * ((2/5)**(3))
# Out:
# 0.15360000000000004

# %%
math.comb(4,2) * ((3/5)**2) * ((2/5)**(2))
# Out:
# 0.3456000000000001

# %%
math.comb(4,3) * ((3/5)**3) * ((2/5)**(1))
# Out:
# 0.34559999999999996

# %%
math.comb(4,4) * ((3/5)**4) * ((2/5)**(0))
# Out:
# 0.1296

# %%
pd.value_counts(red_vals, normalize=True)
# Out:
# <ipython-input-29-e8a38bcf06c1>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(red_vals, normalize=True)
# <ipython-input-29-e8a38bcf06c1>:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pd.value_counts(red_vals, normalize=True)
# 3    0.3472
# 2    0.3358
# 1    0.1579
# 4    0.1334
# 0    0.0257
# Name: proportion, dtype: float64

# %%
from scipy.stats import binom

binom.pmf(n=4, p=3/5, k=4)
# Out:
# 0.1296

# %%
binom.cdf(n=4, p=3/5, k=3)
# Out:
# 0.8704000000000001
